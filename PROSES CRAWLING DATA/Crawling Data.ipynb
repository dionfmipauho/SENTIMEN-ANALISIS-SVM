# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\dions\appdata\local\temp\pip-req-build-zkf0yfsz
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 614d4c2029a62d348ca56598f87c425966aaec66
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\dions\AppData\Local\Temp\pip-req-build-zkf0yfsz'

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools
import tweepy
import requests_oauthlib
import requests

# %%
queries = ['uang mbkm','mbkm','kampus merdeka','merdeka belajar']

# %%
tweets = []
max_tweets = 3000
counter = 0

for query in queries:
    query_string = query
    scraper = sntwitter.TwitterSearchScraper(query_string)

    for tweet in scraper.get_items():
        tweets.append([tweet.user.username, tweet.id, tweet.date, tweet.content])
        counter += 1
        
        if counter >= max_tweets:
            break

    if counter >= max_tweets:
        break
# Out:
# Error retrieving https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22uang%20mbkm%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_
# ...

# %%
tweets = []
max_tweets = 3000
counter = 0

for query in queries:
    query_string = query
    scraper = sntwitter.TwitterSearchScraper(query_string)

    for tweet in scraper.get_items():
        tweets.append([tweet.user.username, tweet.id, tweet.date, tweet.content])
        counter += 1
        
        if counter >= max_tweets:
            break

    if counter >= max_tweets:
        break
# Out:
# C:\Users\dions\AppData\Local\Temp\ipykernel_7504\3917301729.py:10: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.user.username, tweet.id, tweet.date, tweet.content])
# Skipping unrecognised entry ID: 'promoted-tweet-1665629535692369921-26e12c2a39f64436'
# Skipping unrecognised entry ID: 'promoted-tweet-1668261622702383107-26e1478d35e9922c'
# Skipping unrecognised entry ID: 'promoted-tweet-1665786573189943296-26e1b431ebde0b25'
# Skipping unrecognised entry ID: 'promoted-tweet-1665629535692369921-26e106ae86c43b4e'
# Skipping unrecognised entry ID: 'promoted-tweet-1668261622702383107-26e15d939749f1db'
# Skipping unrecognised entry ID: 'promoted-tweet-1666754696156164096-26e1f33e597ab986'
# Skipping unrecognised entry ID: 'promoted-tweet-1665629535692369921-26e1b90a5aa49a93'
# Skipping unrecognised entry ID: 'promoted-tweet-1668261622702383107-26e11169bfce304b'
# ...

# %%
df =pd.DataFrame(tweets, columns=['user', 'id', 'date', 'text'])
df
# Out:
#                  user                   id                      date  \
# 0            2200page  1674657467475824641 2023-06-30 05:53:48+00:00
# 1           sarironan  1674649377972064256 2023-06-30 05:21:39+00:00
# 2             itsmyzn  1674645375918166021 2023-06-30 05:05:45+00:00
# 3          blitteryy2  1674645116005548033 2023-06-30 05:04:43+00:00
# 4     jaehyunsequoia_  1674635441486843904 2023-06-30 04:26:17+00:00
# ...               ...                  ...                       ...
# 5995  nagabiruunjedir  1619954663134203905 2023-01-30 07:04:23+00:00
# 5996       ubsansfess  1619948533922283520 2023-01-30 06:40:02+00:00
# 5997        muhdi_mhd  1619947764884058112 2023-01-30 06:36:58+00:00
# 5998      oizys_tears  1619947556485890048 2023-01-30 06:36:09+00:00
# 5999        muhdi_mhd  1619947503025274881 2023-01-30 06:35:56+00:00
#
#                                                    text
# 0                                      yaallah web mbkm
# ...

# %%
df.to_csv('mbkm2.csv',sep=';')

# %%
df =pd.DataFrame(tweets, columns=['user', 'id', 'date', 'renderedContent'])
df
# Out:
#                  user                   id                      date  \
# 0     ahmadsetiawaan_  1670427707237363712 2023-06-18 13:46:15+00:00
# 1             kulkaxs  1669989255635156993 2023-06-17 08:44:00+00:00
# 2      hoodieseasonie  1668799400720867329 2023-06-14 01:55:56+00:00
# 3       someoneitdark  1666708799561019392 2023-06-08 07:28:38+00:00
# 4        istrimuwnich  1665809319370330112 2023-06-05 19:54:25+00:00
# ...               ...                  ...                       ...
# 7995      michaelrk02  1613191015703392256 2023-01-11 15:08:04+00:00
# 7996      michaelrk02  1613190525821288449 2023-01-11 15:06:07+00:00
# 7997     meditareniaa  1613187912539201538 2023-01-11 14:55:44+00:00
# 7998       ubsansfess  1613185219439517697 2023-01-11 14:45:02+00:00
# 7999      chiavettaaa  1613183969520123905 2023-01-11 14:40:04+00:00
#
#                                         renderedContent
# 0     @Simboloonnn @lovvyou3000 @jogmfs hehe aku jug...
# ...

# %%
df.to_csv('data mbkm lagi2.csv')
